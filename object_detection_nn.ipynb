# %% [markdown]
# <a href="https://colab.research.google.com/github/nhongtat-a11y/codefinity-deep-learning-with-tensorflow/blob/master/object_detection_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection: Custom Keras Model & YOLO Fine-tuning
#
# ## Introduction
# In this chapter, we'll learn how to create a custom object detection model and how to use pre-trained YOLO model. Specifically, we'll focus on detecting only the **"person"** class using our own dataset. We'll explore both the idea of building a model from scratch and why using **transfer learning** with pretrained models like YOLO is often the smarter choice.

# %% [markdown]
# ## Mount Drive Storage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Libraries

# %%
# !pip install git+https://github.com/codefinity-arsenii-dr/codefinity_test_object_detection.git
# Out:
# Collecting git+https://github.com/codefinity-arsenii-dr/codefinity_test_object_detection.git
#   Cloning https://github.com/codefinity-arsenii-dr/codefinity_test_object_detection.git to /tmp/pip-req-build-bfpmmu_x
#   Running command git clone --filter=blob:none --quiet https://github.com/codefinity-arsenii-dr/codefinity_test_object_detection.git /tmp/pip-req-build-bfpmmu_x
#   Resolved https://github.com/codefinity-arsenii-dr/codefinity_test_object_detection.git to commit 3ea6bd99580f0a1434c54b49eafb0f3220a36895
#   Preparing metadata (setup.py) ... done
# Collecting ultralytics (from test-obj-det==1.0.0)
#   Downloading ultralytics-8.4.31-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from test-obj-det==1.0.0) (1.6.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from test-obj-det==1.0.0) (2.19.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from test-obj-det==1.0.0) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from test-obj-det==1.0.0) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from test-obj-det==1.0.0) (4.13.0.92)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (75.2.0)
# Collecting jedi>=0.16 (from IPython->test-obj-det==1.0.0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->test-obj-det==1.0.0) (4.9.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->test-obj-det==1.0.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->test-obj-det==1.0.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->test-obj-det==1.0.0) (3.6.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->test-obj-det==1.0.0) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics->test-obj-det==1.0.0)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->test-obj-det==1.0.0) (0.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->test-obj-det==1.0.0) (0.7.0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics->test-obj-det==1.0.0) (1.35.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->test-obj-det==1.0.0) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->test-obj-det==1.0.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->test-obj-det==1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->test-obj-det==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->test-obj-det==1.0.0) (2026.2.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->test-obj-det==1.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics->test-obj-det==1.0.0) (3.0.3)
# Downloading ultralytics-8.4.31-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.5 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Building wheels for collected packages: test-obj-det
#   Building wheel for test-obj-det (setup.py) ... done
#   Created wheel for test-obj-det: filename=test_obj_det-1.0.0-py3-none-any.whl size=9782 sha256=269fa4f070de52751639f2da9361eb72cb7a001e6cb901391435b96c8efd8af8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ivbfgs3/wheels/32/59/cf/7a2494db0fa8c3ff077b741c2510abe81cd6873ca23e128d0f
# Successfully built test-obj-det
# Installing collected packages: jedi, ultralytics-thop, ultralytics, test-obj-det
# Successfully installed jedi-0.19.2 test-obj-det-1.0.0 ultralytics-8.4.31 ultralytics-thop-2.0.18

# %%
# !pip install keras_cv
# Out:
# Collecting keras_cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras_cv) (26.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras_cv) (2025.11.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (from keras_cv) (4.9.9)
# Collecting keras-core (from keras_cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras_cv) (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras_cv) (0.1.16)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras_cv) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras_cv) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras_cv) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-core->keras_cv) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras-core->keras_cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras-core->keras_cv) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-core->keras_cv) (3.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from keras-core->keras_cv) (0.1.9)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (0.8.3)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (1.14.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (4.3.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (5.29.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (1.17.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (3.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras_cv) (2.1.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (0.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras_cv) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras_cv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras_cv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras_cv) (2026.2.25)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->keras-core->keras_cv) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras_cv) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras_cv) (2.19.2)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets->keras_cv) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv) (1.73.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 6.7 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras_cv
# Successfully installed keras-core-0.1.7 keras_cv-0.9.0

# %%
import os
import random
import requests

import cv2
import numpy as np
import matplotlib.pyplot as plt

import keras_cv
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import ultralytics
from ultralytics import YOLO

import warnings as w
w.simplefilter('ignore')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from test_obj_det import *
from test_obj_det.test import *

# %% [markdown]
# ## Load and Preprocess Dataset

# %% [markdown]
# Before running this cell, make sure you've uploaded the dataset folder to your Google Drive and mounted it using `drive.mount(...)`. This function doesn't accept a Google Drive URL — it needs a local path like `/content/drive/MyDrive/...`. Double-check that the folder contains the correct subdirectories (for example, `images/train`), and update the path below accordingly.

# %%
# === 1. Load the dataset ===
# TODO: Load training and validation data (images, bounding boxes, and original shapes)

train_images, train_labels, train_shapes = load_data("/content/drive/MyDrive", split="train")
val_images, val_labels, val_shapes = load_data("/content/drive/MyDrive", split="val")

# %%
hint1()
# Out:
# Use the `load_data()` function twice — once with `split="train"` and once with `split="val"`.
# Make sure to assign the output to three separate variables each time, like:
# images, labels, shapes = load_data(...)

# %%
solution1()
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #49483e }
# .output_html { background: #272822; color: #F8F8F2 }
# .output_html .c { color: #959077 } /* Comment */
# .output_html .err { color: #ED007E; background-color: #1E0010 } /* Error */
# .output_html .esc { color: #F8F8F2 } /* Escape */
# .output_html .g { color: #F8F8F2 } /* Generic */
# .output_html .k { color: #66D9EF } /* Keyword */
# .output_html .l { color: #AE81FF } /* Literal */
# .output_html .n { color: #F8F8F2 } /* Name */
# .output_html .o { color: #FF4689 } /* Operator */
# .output_html .x { color: #F8F8F2 } /* Other */
# .output_html .p { color: #F8F8F2 } /* Punctuation */
# .output_html .ch { color: #959077 } /* Comment.Hashbang */
# .output_html .cm { color: #959077 } /* Comment.Multiline */
# .output_html .cp { color: #959077 } /* Comment.Preproc */
# .output_html .cpf { color: #959077 } /* Comment.PreprocFile */
# .output_html .c1 { color: #959077 } /* Comment.Single */
# .output_html .cs { color: #959077 } /* Comment.Special */
# .output_html .gd { color: #FF4689 } /* Generic.Deleted */
# .output_html .ge { color: #F8F8F2; font-style: italic } /* Generic.Emph */
# .output_html .ges { color: #F8F8F2; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #F8F8F2 } /* Generic.Error */
# .output_html .gh { color: #F8F8F2 } /* Generic.Heading */
# .output_html .gi { color: #A6E22E } /* Generic.Inserted */
# .output_html .go { color: #66D9EF } /* Generic.Output */
# .output_html .gp { color: #FF4689; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { color: #F8F8F2; font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #959077 } /* Generic.Subheading */
# .output_html .gt { color: #F8F8F2 } /* Generic.Traceback */
# .output_html .kc { color: #66D9EF } /* Keyword.Constant */
# .output_html .kd { color: #66D9EF } /* Keyword.Declaration */
# .output_html .kn { color: #FF4689 } /* Keyword.Namespace */
# .output_html .kp { color: #66D9EF } /* Keyword.Pseudo */
# .output_html .kr { color: #66D9EF } /* Keyword.Reserved */
# .output_html .kt { color: #66D9EF } /* Keyword.Type */
# .output_html .ld { color: #E6DB74 } /* Literal.Date */
# .output_html .m { color: #AE81FF } /* Literal.Number */
# .output_html .s { color: #E6DB74 } /* Literal.String */
# .output_html .na { color: #A6E22E } /* Name.Attribute */
# .output_html .nb { color: #F8F8F2 } /* Name.Builtin */
# .output_html .nc { color: #A6E22E } /* Name.Class */
# .output_html .no { color: #66D9EF } /* Name.Constant */
# .output_html .nd { color: #A6E22E } /* Name.Decorator */
# .output_html .ni { color: #F8F8F2 } /* Name.Entity */
# .output_html .ne { color: #A6E22E } /* Name.Exception */
# .output_html .nf { color: #A6E22E } /* Name.Function */
# .output_html .nl { color: #F8F8F2 } /* Name.Label */
# .output_html .nn { color: #F8F8F2 } /* Name.Namespace */
# .output_html .nx { color: #A6E22E } /* Name.Other */
# .output_html .py { color: #F8F8F2 } /* Name.Property */
# .output_html .nt { color: #FF4689 } /* Name.Tag */
# .output_html .nv { color: #F8F8F2 } /* Name.Variable */
# .output_html .ow { color: #FF4689 } /* Operator.Word */
# .output_html .pm { color: #F8F8F2 } /* Punctuation.Marker */
# .output_html .w { color: #F8F8F2 } /* Text.Whitespace */
# .output_html .mb { color: #AE81FF } /* Literal.Number.Bin */
# .output_html .mf { color: #AE81FF } /* Literal.Number.Float */
# .output_html .mh { color: #AE81FF } /* Literal.Number.Hex */
# .output_html .mi { color: #AE81FF } /* Literal.Number.Integer */
# .output_html .mo { color: #AE81FF } /* Literal.Number.Oct */
# .output_html .sa { color: #E6DB74 } /* Literal.String.Affix */
# .output_html .sb { color: #E6DB74 } /* Literal.String.Backtick */
# .output_html .sc { color: #E6DB74 } /* Literal.String.Char */
# .output_html .dl { color: #E6DB74 } /* Literal.String.Delimiter */
# .output_html .sd { color: #E6DB74 } /* Literal.String.Doc */
# .output_html .s2 { color: #E6DB74 } /* Literal.String.Double */
# .output_html .se { color: #AE81FF } /* Literal.String.Escape */
# .output_html .sh { color: #E6DB74 } /* Literal.String.Heredoc */
# .output_html .si { color: #E6DB74 } /* Literal.String.Interpol */
# .output_html .sx { color: #E6DB74 } /* Literal.String.Other */
# .output_html .sr { color: #E6DB74 } /* Literal.String.Regex */
# .output_html .s1 { color: #E6DB74 } /* Literal.String.Single */
# .output_html .ss { color: #E6DB74 } /* Literal.String.Symbol */
# .output_html .bp { color: #F8F8F2 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #A6E22E } /* Name.Function.Magic */
# .output_html .vc { color: #F8F8F2 } /* Name.Variable.Class */
# .output_html .vg { color: #F8F8F2 } /* Name.Variable.Global */
# .output_html .vi { color: #F8F8F2 } /* Name.Variable.Instance */
# .output_html .vm { color: #F8F8F2 } /* Name.Variable.Magic */
# .output_html .il { color: #AE81FF } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="n">train_images</span><span class="p">,</span> <span class="n">train_labels</span><span class="p">,</span> <span class="n">train_shapes</span> <span class="o">=</span> <span class="n">load_data</span><span class="p">(</span><span class="s2">&quot;/path/to/dataset/data&quot;</span><span class="p">,</span> <span class="n">split</span><span class="o">=</span><span class="s2">&quot;train&quot;</span><span class="p">)</span>
# <span class="n">val_images</span><span class="p">,</span> <span class="n">val_labels</span><span class="p">,</span> <span class="n">val_shapes</span> <span class="o">=</span> <span class="n">load_data</span><span class="p">(</span><span class="s2">&quot;/path/to/dataset/data&quot;</span><span class="p">,</span> <span class="n">split</span><span class="o">=</span><span class="s2">&quot;val&quot;</span><span class="p">)</span>
# </pre></div>

# %%
check1(train_images, train_labels, train_shapes, val_images, val_labels, val_shapes)

# %%
# === 2. Normalize the images ===
# TODO: Normalize image pixel values to the range [0, 1]

train_images_norm = train_images / None
val_images_norm = None

# %%
hint2()

# %%
solution2()

# %%
check2(train_images_norm, val_images_norm)

# %% [markdown]
# ## How to Create Own Object Detection Model with Keras

# %%
# === 3. Build the CNN model ===
# TODO: Define a CNN that has 128x128 3-channel input and outputs 4 values (x, y, w, h) with sigmoid activation.

def build_model():
    model = keras.Sequential([
        layers.Conv2D(___, (3, 3), activation='relu', input_shape=(___, ___, ___)),
        layers.MaxPooling2D(2, 2),
        layers.Conv2D(___, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.Conv2D(___, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.Conv2D(___, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),
        layers.Flatten(),
        layers.Dense(___, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(4, activation='sigmoid')
    ])
    return model

# %%
hint3()

# %%
solution3()

# %%
# === 4. Load or train the model ===
# TODO: Compile the model, train if no weights exist, or load existing weights.

def build_load_model(X_train, y_train, weights_path, optimizer, loss, metrics):
    model = build_model()
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    if os.path.exists(weights_path):
        model.load_weights(weights_path)
    else:
        model.fit(None, None, epochs=None, batch_size=None, validation_split=None)
        model.save_weights(weights_path)

    return model

# %%
hint4()

# %%
solution4()

# %%
# === 5. Initialize and compile the model ===
# TODO: Fill in the correct parameters for training

weights="<your_weights_path>"

model = build_load_model(
    X_train=None,
    y_train=None,
    weights_path=weights,
    optimizer=None,
    loss=None,
    metrics=None
)

# %%
hint5()

# %%
solution5()

# %%
check345(model, weights_path=weights)

# %% [markdown]
# ## Vizualization

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12))
fig.tight_layout(pad=3.0)

for i in range(9):
    ax = axs[i // 3, i % 3]

    # Predict bounding box
    bboxs = model.predict(np.expand_dims(val_images_norm[i], axis=0))
    bbox = bboxs[0]

    # Draw predicted bounding box
    image_with_bbox = draw_bbox(val_images_norm[i], bbox, orig_shape=val_shapes[i], class_name='Person')

    # Show image
    ax.imshow(image_with_bbox)
    ax.axis("off")
    ax.set_title(f"Image {i}")

plt.show()

# %% [markdown]
# ## Why SOTA Models Like YOLO Are Hard to Beat
# While building your own model is a great learning experience, **matching the performance of SOTA models like YOLO, Faster R-CNN, or SSD is extremely difficult** due to:
#
# - **Years of optimization and research** that went into designing these models.
# - Pretrained weights trained on massive datasets (e.g., MS COCO).
# - Advanced training strategies like multi-scale prediction, anchor box optimization, and label smoothing.
# - Access to extensive computing power (e.g., multiple GPUs/TPUs during training).
#
# In short: creating an object detection model from scratch that rivals YOLO in accuracy and speed is a **monumental task** — even for teams of researchers. But the good news is: **you don’t have to**.

# %% [markdown]
# ## Transfer Learning: The Smart Way to Train with Your Dataset
# Training a model from scratch requires a huge amount of data and compute power. That’s why modern computer vision projects often rely on transfer learning — a technique where a model pretrained on a large dataset (like COCO) is fine-tuned for a specific task (like detecting only "person").
#
# ### What is Transfer Learning?
# Transfer learning takes a model that already understands general visual features (like edges, textures, and object parts) and adapts it to a new, smaller dataset. This allows the model to:
#
# - Start with rich, pretrained features,
# - Adapt quickly to your specific object(s),
# - Work well with a limited number of training images,
# - Achieve high accuracy in less time.
#
# In this project, you're working with a YOLOv8 model that's **already fine-tuned** to detect a single object class — person — using a custom dataset. You’ll use it directly for inference, without needing to train it yourself.
#
# > In the next section, you’ll dive deeper into the theory of transfer learning — how it works, why it’s effective, and when to apply it.

# %% [markdown]
# ## Transfer Learning: Training YOLO on Your Own Dataset

# %%
# === 6. Use YOLOv8 to run predictions ===
# TODO: Load a pretrained YOLOv8 model and perform inference

# Link to fine-tuned model: https://codefinity-content-media-v2.s3.eu-west-1.amazonaws.com/courses/ef049f7b-ce21-45be-a9f2-5103360b0655/object_detection_project/models/yolo_trained.pt
yolo_model = YOLO('<yolo_link>')

# Run YOLOv8 prediction on first 9 images from `val_images` with specified confidence treshold
yolo_results = yolo_model.predict([img for img in None], conf=None)

# %%
hint6()

# %%
solution6()

# %%
check6(yolo_model)

# %% [markdown]
# ## Vizualization

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 12))
fig.tight_layout(pad=3.0)

for i in range(9):
    ax = axs[i // 3, i % 3]

    # Convert image to uint8 format for YOLO
    image = val_images[i].astype(np.uint8)

    # Draw bounding boxes
    image_with_yolo = draw_bbox(image, [yolo_results[i]], orig_shape=val_shapes[i])

    # Show image
    ax.imshow(image_with_yolo)
    ax.axis("off")
    ax.set_title(f"YOLOv8 - Image {i}")

plt.show()

# %% [markdown]
# ## Evaluation

# %%
# === 7. Predict on validation set and evaluate ===
# TODO: Generate predictions using the custom model and evaluate them.

pred_labels = model.predict(None)
evaluate_custom_model(None, None)

# %%
hint7()

# %%
solution7()

# %%
check7(model, val_images, val_labels)

# %% [markdown]
# Make sure you've downloaded and extracted the dataset folder from the lesson. Inside that folder, you’ll find a file called `data.yaml`.
#
# Open that file and make the following changes:
#
# * After `train:`, insert the full path to your **training images folder** (e.g. `/content/drive/MyDrive/.../images/train`)
# * After `val:`, insert the full path to your **validation images folder** (e.g. `/content/drive/MyDrive/.../images/val`)
#
# Make sure the paths match the structure of your Google Drive exactly.
#
# Once that's done, return to your notebook and replace `<path_to_data.yaml>` with the full path to your updated `data.yaml` file (e.g. `/content/drive/MyDrive/your_dataset_folder/data.yaml`). This will ensure the YOLO model can find everything it needs to run properly.

# %%
# === 8. Evaluate YOLOv8 model ===
# TODO: Validate the YOLO model using the correct data.yaml file

metrics = yolo_model.val(data="<path_to_data.yaml>")

# TODO: Extract metrics from the `metrics` object

precision = None
recall = None
map50 = None
map = None

print("\nYOLO results:")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"mAP50: {map50:.4f}")
print(f"mAP50-95: {map:.4f}")

# %%
hint8()

# %%
solution8()

# %%
check8(metrics)

# %% [markdown]
# ## Conclusion
#
# In this project, you implemented and compared **two different object detection approaches:**
#
# ### 1. Custom Object Detection CNN
# You designed and trained your own convolutional neural network from scratch to predict bounding boxes in images.
#
# **Pros:**
#
# - Full control over the architecture and training process;
# - Great for learning core concepts behind object detection;
# - Lightweight compared to heavy pretrained models;
# - Easier to adapt for unique or very small datasets.
#
# **Cons:**
#
# - Requires more data and compute power to reach high accuracy;
# - Slower to train and tune manually;
# - May not match the performance of pretrained models on complex tasks.
#
# ### 2. YOLO with Transfer Learning
# You used **a fine-tuned YOLOv8 model**, which has been pretrained on a large dataset and adapted to your task.
#
# **Pros:**
#
# - State-of-the-art performance out of the box;
# - Faster and more accurate on real-world data;
# - Requires minimal training data and time (fine-tuning is already done);
# - Easy to use with `ultralytics` library and robust tools.
#
# **Cons:**
#
# - Less flexible - architecture and training are abstracted away;
# - Heavier models may not run efficiently on resource-limited devices;
# - Harder to understand or customize without deep experience.
#
# **Key Takeaways**
#
# 1. Building your own model helps you **understand the mechanics of object detection** and build a foundation in deep learning;
# 2. Using transfer learning with a pretrained model like YOLO is a powerful way to **achieve high performance quickly**;
# 3. In practice, a combination of both skills - understanding the fundamentals and knowing when to leverage transfer learning - is the most valuable.
